# %%
from huggingface_hub import HfApi
api = HfApi()

api.upload_folder(
    folder_path="../Dataset",
    repo_id="ZhuofengLi/TEG-Datasets",
    repo_type="dataset",
    token="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",
	ignore_patterns=["**/logs/*.txt", "**/.ipynb_checkpoints", "**/__pycache__", "**/.cache", "**/embcache", "**/LinkPrediction"]
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://huggingface.co/api/datasets/ZhuofengLi/TEG-Datasets/commit/main
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# Cell In[3], line 4
#       1 from huggingface_hub import HfApi
#       2 api = HfApi()
# ----> 4 api.upload_folder(
#       5     folder_path="../Dataset",
#       6     repo_id="ZhuofengLi/TEG-Datasets",
#       7     repo_type="dataset",
#       8     token="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",
#       9 	ignore_patterns=["**/logs/*.txt", "**/.ipynb_checkpoints", "**/__pycache__", "**/.cache", "**/embcache", "**/LinkPrediction"]
#      10 )
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py:1485, in future_compatible.<locals>._inner(self, *args, **kwargs)
#    1482     return self.run_as_future(fn, self, *args, **kwargs)
#    1484 # Otherwise, call the function normally
# -> 1485 return fn(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py:5007, in HfApi.upload_folder(self, repo_id, folder_path, path_in_repo, commit_message, commit_description, token, repo_type, revision, create_pr, parent_commit, allow_patterns, ignore_patterns, delete_patterns, multi_commits, multi_commits_verbose, run_as_future)
#    5003     # Defining a CommitInfo object is not really relevant in this case
#    5004     # Let's return early with pr_url only (as string).
#    5005     return pr_url
# -> 5007 commit_info = self.create_commit(
#    5008     repo_type=repo_type,
#    5009     repo_id=repo_id,
#    5010     operations=commit_operations,
#    5011     commit_message=commit_message,
#    5012     commit_description=commit_description,
#    5013     token=token,
#    5014     revision=revision,
#    5015     create_pr=create_pr,
#    5016     parent_commit=parent_commit,
#    5017 )
#    5019 # Create url to uploaded folder (for legacy return value)
#    5020 if create_pr and commit_info.pr_url is not None:
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py:1485, in future_compatible.<locals>._inner(self, *args, **kwargs)
#    1482     return self.run_as_future(fn, self, *args, **kwargs)
#    1484 # Otherwise, call the function normally
# -> 1485 return fn(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py:3995, in HfApi.create_commit(self, repo_id, operations, commit_message, commit_description, token, repo_type, revision, create_pr, num_threads, parent_commit, run_as_future)
#    3993 try:
#    3994     commit_resp = get_session().post(url=commit_url, headers=headers, data=data, params=params)
# -> 3995     hf_raise_for_status(commit_resp, endpoint_name="commit")
#    3996 except RepositoryNotFoundError as e:
#    3997     e.append_to_message(_CREATE_COMMIT_NO_REPO_ERROR_MESSAGE)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_http.py:460, in hf_raise_for_status(response, endpoint_name)
#     456 elif response.status_code == 400:
#     457     message = (
#     458         f"\n\nBad request for {endpoint_name} endpoint:" if endpoint_name is not None else "\n\nBad request:"
#     459     )
# --> 460     raise _format(BadRequestError, message, response) from e
#     462 elif response.status_code == 403:
#     463     message = (
#     464         f"\n\n{response.status_code} Forbidden: {error_message}."
#     465         + f"\nCannot access content at: {response.url}."
#     466         + "\nMake sure your token has the correct permissions."
#     467     )
#
# BadRequestError: (Request ID: Root=1-670fa1af-2c5d94143eccd2c7569a6d74;0e075680-e501-433e-9990-4f54e5d9d6b8)
#
# Bad request for commit endpoint:
# It appears that one or more of your files contain valid Hugging Face secrets, such as tokens or API keys. It is important to keep your secrets private and not expose them in code that is publicly accessible. Read more: https://huggingface.co/docs/hub/spaces-overview#managing-secrets Offending files: - goodreads_children/raw/process_final_goodreads.ipynb (ref: refs/heads/main, token: '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')
# It appears that one or more of your files contain valid Hugging Face secrets, such as tokens or API keys. It is important to keep your secrets private and not expose them in code that is publicly accessible. Read more: https://huggingface.co/docs/hub/spaces-overview#managing-secrets  Offending files:   - goodreads_children/raw/process_final_goodreads.ipynb (ref: refs/heads/main, token: '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')
